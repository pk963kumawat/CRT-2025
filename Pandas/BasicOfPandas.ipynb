# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("Used_Bikes.csv")

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.head() # by default 5 rows form top
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail() # return by default 5 rows form bottom
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.tail(10)
# Out:
#                          bike_name     price         city  kms_driven  \
# 32638        Yamaha Fazer 25 250cc  123000.0       Kadapa     14500.0
# 32639  Royal Enfield Classic 350cc   95500.0        Delhi     18000.0
# 32640       Hero Passion Pro 100cc   32000.0        Delhi     12000.0
# 32641          Bajaj Avenger 220cc   41000.0        Delhi     20245.0
# 32642           Hero Passion 100cc   15000.0  Perumbavoor     35000.0
# 32643       Hero Passion Pro 100cc   39000.0        Delhi     22000.0
# 32644         TVS Apache RTR 180cc   30000.0       Karnal      6639.0
# 32645     Bajaj Avenger Street 220   60000.0        Delhi     20373.0
# 32646    Hero Super Splendor 125cc   15600.0       Jaipur     84186.0
# 32647           Bajaj Pulsar 150cc   22000.0         Pune     60857.0
#
#               owner   age  power          brand
# 32638   First Owner   4.0  250.0         Yamaha
# 32639   First Owner   8.0  350.0  Royal Enfield
# 32640   First Owner   6.0  100.0           Hero
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.describe() # desribe the data in detail like mean max,min,25%,50%,75%,std,count
# Out:
#               price     kms_driven           age         power
# count  3.264800e+04   32648.000000  32648.000000  32648.000000
# mean   6.829542e+04   26344.625184      8.048211    213.511302
# std    9.071860e+04   22208.527695      4.031700    134.428868
# min    4.400000e+03       1.000000      1.000000    100.000000
# 25%    2.500000e+04   12000.000000      5.000000    150.000000
# 50%    4.300000e+04   20373.000000      7.000000    150.000000
# 75%    8.000000e+04   35000.000000     10.000000    220.000000
# max    1.900000e+06  750000.000000     63.000000   1800.000000

# %%
df.dtypes # given data typeof featuers/columns
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df.shape # gives shape of datset (row,columns)
# Out:
# (32648, 8)

# %%
df["bike_name"] # used for printing pactiular feature/columns of dataset
# Out:
# 0          TVS Star City Plus Dual Tone 110cc
# 1                 Royal Enfield Classic 350cc
# 2                        Triumph Daytona 675R
# 3                        TVS Apache RTR 180cc
# 4        Yamaha FZ S V 2.0 150cc-Ltd. Edition
#                          ...
# 32643                  Hero Passion Pro 100cc
# 32644                    TVS Apache RTR 180cc
# 32645                Bajaj Avenger Street 220
# 32646               Hero Super Splendor 125cc
# 32647                      Bajaj Pulsar 150cc
# Name: bike_name, Length: 32648, dtype: object

# %%
df['age'].head(10)
# Out:
# 0    3.0
# 1    4.0
# 2    8.0
# 3    4.0
# 4    3.0
# 5    6.0
# 6    3.0
# 7    3.0
# 8    3.0
# 9    7.0
# Name: age, dtype: float64

# %%
brand_name_df=df["brand"]

# %%
brand_name_df
# Out:
# 0                  TVS
# 1        Royal Enfield
# 2              Triumph
# 3                  TVS
# 4               Yamaha
#              ...
# 32643             Hero
# 32644              TVS
# 32645            Bajaj
# 32646             Hero
# 32647            Bajaj
# Name: brand, Length: 32648, dtype: object

# %%
brand_name_df.unique().shape
# Out:
# (23,)

# %%
brand_name_df.nunique()
# Out:
# 23

# %%
df["bike_name"].nunique() # nunique use of calculting unique rows
# Out:
# 471

# %%
df.iloc[0] # particular row print with feature
# Out:
# bike_name     TVS Star City Plus Dual Tone 110cc
# price                                    35000.0
# city                                   Ahmedabad
# kms_driven                               17654.0
# owner                                First Owner
# age                                          3.0
# power                                      110.0
# brand                                        TVS
# Name: 0, dtype: object

# %%
df.loc[0:5] # particular subset of rows print [starting : ending]
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                      Yamaha FZs 150cc   53499.0      Delhi     25000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha
# 5  First Owner  6.0  150.0         Yamaha

# %%
df.isnull() #print true if null value exit otherwise flase
# Out:
#        bike_name  price   city  kms_driven  owner    age  power  brand
# 0          False  False  False       False  False  False  False  False
# 1          False  False  False       False  False  False  False  False
# 2          False  False  False       False  False  False  False  False
# 3          False  False  False       False  False  False  False  False
# 4          False  False  False       False  False  False  False  False
# ...          ...    ...    ...         ...    ...    ...    ...    ...
# 32643      False  False  False       False  False  False  False  False
# 32644      False  False  False       False  False  False  False  False
# 32645      False  False  False       False  False  False  False  False
# 32646      False  False  False       False  False  False  False  False
# 32647      False  False  False       False  False  False  False  False
#
# [32648 rows x 8 columns]

# %%
df.isnull().sum() # doing sun of null values in each other
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.duplicated() # gives true if duplicate value exit otherwise false
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum() # doing sum of duplicate roes
# Out:
# 25324

# %%
df.drop_duplicates() # dropping the duplicates value not permantely
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.duplicated().sum()
# Out:
# 25324

# %%
df.drop_duplicates(inplace=True) # dropping the duplicates value not permantely

# %%
df.duplicated().sum() # all duplicate are removed form data sets
# Out:
# 0

# %%
df.dropna() # all values drop null values forn dataset not permently
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.dropna(inplace=True) # all values drop null values forn dataset not permently

# %%
df['age'].isnull().sum() # particular feature null count sum
# Out:
# 0

# %%
df['bike_name'].duplicated().sum()
# Out:
# 6853

# %%
df['brand'].duplicated().sum()
# Out:
# 7301

# %%
df['brand'].nunique() # numbers of unique values in brand column
# Out:
# 23

# %%
df.fillna(0) # filling 0 where null value exit
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df['brand'].fillna(df['price'].mean()) # filling mean of price frature in the null values in brand feature
# Out:
# 0                   TVS
# 1         Royal Enfield
# 2               Triumph
# 3                   TVS
# 4                Yamaha
#              ...
# 9362               Hero
# 9369              Bajaj
# 9370    Harley-Davidson
# 9371              Bajaj
# 9372              Bajaj
# Name: brand, Length: 7324, dtype: object

# %%
#df['brand'].fillna(df['price'].mean(),inplace=True) # filling mean of price frature in the null values in brand feature

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.rename(columns={"price":"price of bikes"})
# Out:
#                                  bike_name  price of bikes       city  \
# 0       TVS Star City Plus Dual Tone 110cc         35000.0  Ahmedabad
# 1              Royal Enfield Classic 350cc        119900.0      Delhi
# 2                     Triumph Daytona 675R        600000.0      Delhi
# 3                     TVS Apache RTR 180cc         65000.0  Bangalore
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition         80000.0  Bangalore
# ...                                    ...             ...        ...
# 9362             Hero Hunk Rear Disc 150cc         25000.0      Delhi
# 9369                   Bajaj Avenger 220cc         35000.0  Bangalore
# 9370        Harley-Davidson Street 750 ABS        450000.0    Jodhpur
# 9371                 Bajaj Dominar 400 ABS        139000.0  Hyderabad
# 9372              Bajaj Avenger Street 220         80000.0  Hyderabad
#
#       kms_driven        owner  age  power            brand
# 0        17654.0  First Owner  3.0  110.0              TVS
# ...

# %%
df.rename(columns={"price":"price of bikes"},inplace=True)

# %%
df
# Out:
#                                  bike_name  price of bikes       city  \
# 0       TVS Star City Plus Dual Tone 110cc         35000.0  Ahmedabad
# 1              Royal Enfield Classic 350cc        119900.0      Delhi
# 2                     Triumph Daytona 675R        600000.0      Delhi
# 3                     TVS Apache RTR 180cc         65000.0  Bangalore
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition         80000.0  Bangalore
# ...                                    ...             ...        ...
# 9362             Hero Hunk Rear Disc 150cc         25000.0      Delhi
# 9369                   Bajaj Avenger 220cc         35000.0  Bangalore
# 9370        Harley-Davidson Street 750 ABS        450000.0    Jodhpur
# 9371                 Bajaj Dominar 400 ABS        139000.0  Hyderabad
# 9372              Bajaj Avenger Street 220         80000.0  Hyderabad
#
#       kms_driven        owner  age  power            brand
# 0        17654.0  First Owner  3.0  110.0              TVS
# ...

# %%
df.sort_index(ascending=False) # Indexing sorting in decending order

# %%
df
# Out:
#                                  bike_name  price of bikes       city  \
# 9372              Bajaj Avenger Street 220         80000.0  Hyderabad
# 9371                 Bajaj Dominar 400 ABS        139000.0  Hyderabad
# 9370        Harley-Davidson Street 750 ABS        450000.0    Jodhpur
# 9369                   Bajaj Avenger 220cc         35000.0  Bangalore
# 9362             Hero Hunk Rear Disc 150cc         25000.0      Delhi
# ...                                    ...             ...        ...
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition         80000.0  Bangalore
# 3                     TVS Apache RTR 180cc         65000.0  Bangalore
# 2                     Triumph Daytona 675R        600000.0      Delhi
# 1              Royal Enfield Classic 350cc        119900.0      Delhi
# 0       TVS Star City Plus Dual Tone 110cc         35000.0  Ahmedabad
#
#       kms_driven        owner  age  power            brand
# 9372      7127.0  First Owner  5.0  220.0            Bajaj
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bike_name       7324 non-null   object
#  1   price of bikes  7324 non-null   float64
#  2   city            7324 non-null   object
#  3   kms_driven      7324 non-null   float64
#  4   owner           7324 non-null   object
#  5   age             7324 non-null   float64
#  6   power           7324 non-null   float64
#  7   brand           7324 non-null   object
# dtypes: float64(4), object(4)
# memory usage: 515.0+ KB

# %%
char_column = df.select_dtypes(include='object') # select  paraticular data types

# %%
char_column
# Out:
#                                  bike_name       city        owner  \
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# ...                                    ...        ...          ...
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
#
#                 brand
# 9372            Bajaj
# 9371            Bajaj
# 9370  Harley-Davidson
# 9369            Bajaj
# 9362             Hero
# ...

# %%
num_column = df.select_dtypes(exclude='O') # except objects data type link int , float print

# %%
num_column
# Out:
#       price of bikes  kms_driven  age  power
# 9372         80000.0      7127.0  5.0  220.0
# 9371        139000.0     21300.0  4.0  400.0
# 9370        450000.0      3430.0  4.0  750.0
# 9369         35000.0     60000.0  9.0  220.0
# 9362         25000.0     48587.0  8.0  150.0
# ...              ...         ...  ...    ...
# 4            80000.0     10000.0  3.0  150.0
# 3            65000.0     16329.0  4.0  180.0
# 2           600000.0       110.0  8.0  675.0
# 1           119900.0     11000.0  4.0  350.0
# 0            35000.0     17654.0  3.0  110.0
#
# [7324 rows x 4 columns]
