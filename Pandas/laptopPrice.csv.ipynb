# %% [markdown]
# ### **Project laptop Price Prediction**

# %%
import pandas as pd

# %%
df = pd.read_csv("laptopPrice.csv")

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.tail()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.size
# Out:
# 15637

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.describe()  # describe data like mean, count, min, max, std
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
cat_column = df.select_dtypes(include="O")

# %%
cat_column
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
num_column = df.select_dtypes(exclude="O")

# %%
num_column
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [823 rows x 3 columns]

# %%
cat_column["brand"].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
cat_column["brand"].nunique()
# Out:
# 8

# %%
cat_column["brand"].unique().size
# Out:
# 8

# %%
cat_column["processor_brand"].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
cat_column['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
cat_column['processor_name'].unique().size
# Out:
# 11

# %%
cat_column['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
cat_column['processor_gnrtn'].unique().size
# Out:
# 8

# %%
cat_column.nunique()
# Out:
# brand               8
# processor_brand     3
# processor_name     11
# processor_gnrtn     8
# ram_gb              4
# ram_type            6
# ssd                 7
# hdd                 4
# os                  3
# os_bit              2
# graphic_card_gb     5
# weight              3
# warranty            4
# Touchscreen         2
# msoffice            2
# rating              5
# dtype: int64

# %%
cat_column["brand"].value_counts()   # Return a Series containing counts of unique values.
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
apple = df[cat_column["brand"] == "APPLE"]  # camparison and finding matching data

# %%
apple
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
asus = df["brand"] == "ASUS"

# %%
df[asus]
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
asus.sum()
# Out:
# 249

# %%
apple['processor_brand'].unique()
# Out:
# array(['Intel', 'M1'], dtype=object)

# %%
apple_M1_chip = apple[apple['processor_brand'] == 'M1']

# %%
apple_M1_chip.head()
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
#
#         ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 599  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 600  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 601  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 602  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 603  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
# ...

# %%
apple_M1_chip[apple_M1_chip['Touchscreen'] == 'No']
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# 607  APPLE              M1             M1            10th   8 GB     DDR4
# 608  APPLE              M1             M1            10th   8 GB     DDR4
# 609  APPLE              M1             M1            10th   8 GB     DDR4
# 610  APPLE              M1             M1            10th   8 GB     DDR4
# ...

# %%
apple_M1_chip[apple_M1_chip['Touchscreen'] == 'Yes']
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
apple['processor_brand'].unique()
# Out:
# array(['Intel', 'M1'], dtype=object)

# %%
apple_Intel = apple[apple['processor_brand'] == 'Intel']

# %%
apple_Intel
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
#
#          ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 309   512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 310   512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 407  1024 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 408  1024 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
#     msoffice   Price   rating  Number of Ratings  Number of Reviews
# 309       No  159990  4 stars                 32                  5
# 310       No  172090  4 stars                108                 13
# ...

# %%
apple_Intel_8GB = apple_Intel[apple_Intel['ram_gb'] == '8GB']

# %%
apple_Intel_8GB
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
# asus, processor gen =10, ddr3, os = win ,graphic =4gb, <50000

# %%
asus = df[df['brand'] == "ASUS"]

# %%
asus.head()
# Out:
#   brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0  ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3  ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4  ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5  ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6  ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
# 5    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
# 6    0 GB   512 GB  Windows  32-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
asus_10th = asus[asus["processor_gnrtn"] == "10th"]

# %%
asus_10th.head()
# Out:
#    brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3   ASUS           Intel        Core i5            10th   8 GB     DDR4
# 7   ASUS           Intel        Core i5            10th   8 GB     DDR4
# 27  ASUS           Intel        Core i3            10th   8 GB     DDR4
# 60  ASUS           Intel        Core i3            10th   4 GB     DDR4
#
#        ssd      hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 0     0 GB  1024 GB  Windows  64-bit            0 GB      Casual  No warranty
# 3   512 GB     0 GB  Windows  32-bit            2 GB      Casual  No warranty
# 7     0 GB  1024 GB  Windows  32-bit            2 GB      Casual  No warranty
# 27  256 GB     0 GB  Windows  64-bit            0 GB  ThinNlight  No warranty
# 60  256 GB     0 GB  Windows  64-bit            0 GB      Casual       1 year
#
# ...

# %%
asus_10th_DDR3 = asus_10th[asus_10th['ram_type'] == "DDR3"]
asus_10th_DDR3
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
asus_10th_DDR3_Win = asus_10th_DDR3[asus_10th_DDR3['os'] == 'Windows']

# %%
asus_10th_DDR3_Win
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
asus_10th_DDR3_Win_4Gb = asus_10th_DDR3_Win[asus_10th_DDR3_Win['graphic_card_gb'] == '4GB']

# %%
asus_10th_DDR3_Win_4Gb.size
# Out:
# 0

# %%
asus_10th_DDR3_Win_4Gb_50000 = asus_10th_DDR3_Win_4Gb[asus_10th_DDR3_Win_4Gb['Price'] <= 50000]

# %%
asus_10th_DDR3_Win_4Gb_50000.size
# Out:
# 0

# %%
asus_10th.size
# Out:
# 1102

# %%
# acer genname core i5,8gb ssd <512 os-win, gr - 4GB,touch,<70000

# %%
df.head(20)
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0     ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1   Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2   Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3     ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4     ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5     ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6     ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7     ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8   Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9     acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 10    acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 11    acer             AMD        Ryzen 5            10th   4 GB     DDR4
# ...

# %%
acer = df[df['brand'] == "acer"]

# %%
acer.head()
# Out:
#    brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 9   acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 10  acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 11  acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 31  acer           Intel        Core i3            11th   8 GB     DDR4
# 64  acer           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#        ssd     hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 9     0 GB  512 GB  Windows  32-bit            4 GB      Casual  No warranty
# 10    0 GB  512 GB  Windows  32-bit            6 GB      Casual  No warranty
# 11    0 GB  512 GB  Windows  32-bit            4 GB      Casual  No warranty
# 31  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
# 64    0 GB  512 GB  Windows  32-bit            0 GB      Casual  No warranty
#
# ...

# %%
acer_i5 = acer[acer['processor_name'] == 'Core i5']

# %%
acer_i5.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
# 197  acer           Intel        Core i5   Not Available   8 GB   LPDDR4
# 198  acer           Intel        Core i5            10th   8 GB   LPDDR4
# 207  acer           Intel        Core i5             7th   8 GB     DDR3
# 210  acer           Intel        Core i5             8th   8 GB     DDR3
#
#         ssd     hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 196    0 GB  512 GB  Windows  32-bit            4 GB      Casual  No warranty
# 197    0 GB  512 GB  Windows  32-bit            0 GB      Casual       1 year
# 198    0 GB  512 GB      DOS  32-bit            0 GB      Casual  No warranty
# 207  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
# 210  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
#
# ...

# %%
acer_i5_8GB = acer_i5[acer_i5['ram_gb'] == '8 GB']

# %%
acer_i5_8GB.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
# 197  acer           Intel        Core i5   Not Available   8 GB   LPDDR4
# 198  acer           Intel        Core i5            10th   8 GB   LPDDR4
# 207  acer           Intel        Core i5             7th   8 GB     DDR3
# 210  acer           Intel        Core i5             8th   8 GB     DDR3
#
#         ssd     hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 196    0 GB  512 GB  Windows  32-bit            4 GB      Casual  No warranty
# 197    0 GB  512 GB  Windows  32-bit            0 GB      Casual       1 year
# 198    0 GB  512 GB      DOS  32-bit            0 GB      Casual  No warranty
# 207  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
# 210  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
#
# ...

# %%
acer_i5_8GB_512 = acer_i5_8GB[acer_i5_8GB['ssd']<= '512 GB']

# %%
acer_i5_8GB_512.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
# 197  acer           Intel        Core i5   Not Available   8 GB   LPDDR4
# 198  acer           Intel        Core i5            10th   8 GB   LPDDR4
# 207  acer           Intel        Core i5             7th   8 GB     DDR3
# 210  acer           Intel        Core i5             8th   8 GB     DDR3
#
#         ssd     hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 196    0 GB  512 GB  Windows  32-bit            4 GB      Casual  No warranty
# 197    0 GB  512 GB  Windows  32-bit            0 GB      Casual       1 year
# 198    0 GB  512 GB      DOS  32-bit            0 GB      Casual  No warranty
# 207  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
# 210  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
#
# ...

# %%
acer_i5_8GB_512_Win = acer_i5_8GB_512[acer_i5_8GB_512['os'] == 'Windows']

# %%
acer_i5_8GB_512_Win.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
# 197  acer           Intel        Core i5   Not Available   8 GB   LPDDR4
# 207  acer           Intel        Core i5             7th   8 GB     DDR3
# 210  acer           Intel        Core i5             8th   8 GB     DDR3
# 212  acer           Intel        Core i5             8th   8 GB     DDR4
#
#         ssd     hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 196    0 GB  512 GB  Windows  32-bit            4 GB      Casual  No warranty
# 197    0 GB  512 GB  Windows  32-bit            0 GB      Casual       1 year
# 207  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
# 210  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
# 212  256 GB    0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
#
# ...

# %%
acer_i5_8GB_512_Win_4GB = acer_i5_8GB_512_Win[acer_i5_8GB_512_Win['graphic_card_gb'] == '4 GB']

# %%
acer_i5_8GB_512_Win_4GB
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
# 325  acer           Intel        Core i5             8th   8 GB     DDR4
#
#         ssd     hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 196    0 GB  512 GB  Windows  32-bit            4 GB  Casual  No warranty
# 325  512 GB    0 GB  Windows  64-bit            4 GB  Casual       1 year
#
#     Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 196          No       No  50990  4 stars              10966               1185
# 325          No       No  99500  3 stars                  0                  0

# %%
acer_i5_8GB_512_Win_4GB_touch = acer_i5_8GB_512_Win_4GB[acer_i5_8GB_512_Win_4GB['Touchscreen']=='No']

# %%
acer_i5_8GB_512_Win_4GB_touch
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
# 325  acer           Intel        Core i5             8th   8 GB     DDR4
#
#         ssd     hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 196    0 GB  512 GB  Windows  32-bit            4 GB  Casual  No warranty
# 325  512 GB    0 GB  Windows  64-bit            4 GB  Casual       1 year
#
#     Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 196          No       No  50990  4 stars              10966               1185
# 325          No       No  99500  3 stars                  0                  0

# %%
acer_i5_8GB_512_Win_4GB_touch_70000 = acer_i5_8GB_512_Win_4GB_touch[acer_i5_8GB_512_Win_4GB_touch['Price']<=70000]

# %%
acer_i5_8GB_512_Win_4GB_touch_70000
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
#
#       ssd     hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 196  0 GB  512 GB  Windows  32-bit            4 GB  Casual  No warranty
#
#     Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 196          No       No  50990  4 stars              10966               1185
